# %%
#TAREA #4 METODO BISECCION Y FALSA POSICION#

#EJERCICIO #1#
import matplotlib.pyplot as plt
lxr = list()

def biseccion(xl = 6, xu = 7):
  print("METODO DE BISECCION: ")
  print("Siendo Xl = 6, Xu = 7")
  fxu=((-0.5 * (xu**2)) + (2.5 * xu) + 4.5)
  fxl = ((-0.5 * (xl**2)) + (2.5 * xl) + 4.5)
  if (fxu * fxl < 0):
     xr = (xl + xu) / 2
     fxr = ((-0.5 * (xr**2)) + (2.5 * xr) + 4.5)
     print("El valor de Xr es: " + str(xr))
     lxr.append(xr)
     num = 1
     while num < 4:
         num = num + 1
         if (fxu * fxr < 0):             
             xl = xr
             fxu=((-0.5 * (xu**2)) + (2.5 * xu) + 4.5)
             fxl = ((-0.5 * (xl**2)) + (2.5 * xl) + 4.5)
             xr = (xl + xu) / 2
             fxr = ((-0.5 * (xr**2)) + (2.5 * xr) + 4.5)             
             print("El valor de Xr es: " + str(xr))
             lxr.append(xr)
         if (fxl * fxr < 0):
             xu = xr
             fxu=((-0.5 * (xu**2)) + (2.5 * xu) + 4.5)
             fxl = ((-0.5 * (xl**2)) + (2.5 * xl) + 4.5)
             xr = (xl + xu) / 2
             fxr = ((-0.5 * (xr**2)) + (2.5 * xr) + 4.5)
             print("El valor de Xr es: " + str(xr))
             lxr.append(xr)
         if (fxu * fxr > 0 and fxl * fxr > 0):
             print("No tiene raiz")
  else:
     print("No tiene raiz")
biseccion()
plt.plot(lxr)  
plt.show()
# Out:
# METODO DE BISECCION:
# Siendo Xl = 6, Xu = 7
# El valor de Xr es: 6.5
# El valor de Xr es: 6.25
# El valor de Xr es: 6.375
# El valor de Xr es: 6.4375
# El valor de Xr es: 6.40625

# %%
#EJERCICIO #1#
import matplotlib.pyplot as plt

def falsaPosicion(xu = 7, xl = 6):
    print("METODO DE FALSA POSICION: ")
    print("Siendo Xl = 6, Xu = 7")
    fxu=((-0.5 * (xu**2)) + (2.5 * xu) + 4.5)
    fxl = ((-0.5 * (xl**2)) + (2.5 * xl) + 4.5)
    lxr = list()
    if(fxu * fxl < 0):
        xr = (xu - ((fxu * (xl - xu) / (fxl - fxu))))
        fxr =((-0.5 * (xr**2)) + (2.5 * xr) + 4.5)
        lxr.append(xr)
        print("El valor de Xr es: " + str(xr))
        er = 1
        while er > (10**-5):
            if(fxu * fxr < 0):
                xl = xr
                fxl =((-0.5 * (xl**2)) + (2.5 * xl) + 4.5)
                fxu =((-0.5 * (xu**2)) + (2.5 * xu) + 4.5)
                xr = (xu - ((fxu * (xl - xu) / (fxl - fxu))))
                fxr =((-0.5 * (xr**2)) + (2.5 * xr) + 4.5)
                er=(xr-xl)/xr
                lxr.append(xr)
                print("El valor de Xr es: " + str(xr))
            if (fxl * fxr < 0):
                xu=xr
                fxl = ((-0.5 * (xl**2)) + (2.5 * xl) + 4.5)
                fxu = ((-0.5 * (xu**2)) + (2.5 * xu) + 4.5)
                xr = (xu - ((fxu * (xl - xu) / (fxl - fxu))))
                fxr = ((-0.5 * (xr**2)) + (2.5 * xr) + 4.5)
                er = (xr - xl) / xr
                lxr.append(xr)
                print("El valor de Xr es: " + str(xr))
            if (fxu * fxr > 0 and fxl * fxr > 0):
                print("No tiene raiz, fin del programa")
        plt.plot(lxr)
        plt.show
    else:
        print("No tiene raiz, fin del programa")
falsaPosicion()
# Out:
# METODO DE FALSA POSICION:
# Siendo Xl = 6, Xu = 7
# El valor de Xr es: 6.375
# El valor de Xr es: 6.402985074626866
# El valor de Xr es: 6.404973357015986
# El valor de Xr es: 6.4051141166525785
# El valor de Xr es: 6.405124079149171

# %%
#EJERCICIO #2#
import matplotlib.pyplot as plt
lxr = list()

def biseccion(xl = 0, xu = 1):
  print("METODO DE BISECCION: ")
  fxu=((5 * (xu**3)) + (5 * xu**2) + (6 * xu) - 2)
  fxl = ((5 * (xl**3)) + (5 * xl**2) + (6 * xl) - 2)
  if (fxu * fxl < 0):
     xr = (xl + xu) / 2
     fxr = ((5 * (xu**3)) + (5 * xu**2) + (6 * xu) - 2)
     print("El valor de Xr es: " + str(xr))
     lxr.append(xr)
     num = 1
     while num < 4:
         num = num + 1
         if (fxu * fxr < 0):             
             xl = xr
             fxu=((5 * (xu**3)) + (5 * xu**2) + (6 * xu) - 2)
             fxl = ((5 * (xl**3)) + (5 * xl**2) + (6 * xl) - 2)
             xr = (xl + xu) / 2
             fxr = ((5 * (xu**3)) + (5 * xu**2) + (6 * xu) - 2)             
             print("El valor de Xr es: " + str(xr))
             lxr.append(xr)
         if (fxl * fxr < 0):
             xu = xr
             fxu=((5 * (xu**3)) + (5 * xu**2) + (6 * xu) - 2)
             fxl = ((5 * (xl**3)) + (5 * xl**2) + (6 * xl) - 2)
             xr = (xl + xu) / 2
             fxr = ((5 * (xu**3)) + (5 * xu**2) + (6 * xu) - 2)
             print("El valor de Xr es: " + str(xr))
             lxr.append(xr)
         if (fxu * fxr > 0 and fxl * fxr > 0):
             print("No tiene raiz")
  else:
     print("No tiene raiz")
biseccion()
plt.plot(lxr)  
plt.show()
# Out:
# METODO DE BISECCION:
# El valor de Xr es: 0.5
# El valor de Xr es: 0.25
# El valor de Xr es: 0.125
# No tiene raiz
# No tiene raiz

# %%
#EJERCICIO #3#
import matplotlib.pyplot as plt
lxr = list()

def biseccion(xl = 0.5, xu = 2):
  print("METODO DE BISECCION: ")
  fxu=((math.log(xu**2)) - 0.7)
  fxl = ((math.log(xl**2)) - 0.7)
  if (fxu * fxl < 0):
     xr = (xl + xu) / 2
     fxr = ((math.log(xr**2)) - 0.7)
     print("El valor de Xr es: " + str(xr))
     lxr.append(xr)
     num = 1
     while num < 2:
         num = num + 1
         if (fxu * fxr < 0):             
             xl = xr
             fxu=((math.log(xu**2)) - 0.7)
             fxl = ((math.log(xl**2)) - 0.7)
             xr = (xl + xu) / 2
             fxr = ((math.log(xr**2)) - 0.7)            
             print("El valor de Xr es: " + str(xr))
             lxr.append(xr)
         if (fxl * fxr < 0):
             xu = xr
             fxu=((math.log(xu**2)) - 0.7)
             fxl = ((math.log(xl**2)) - 0.7)
             xr = (xl + xu) / 2
             fxr = ((math.log(xr**2)) - 0.7)
             print("El valor de Xr es: " + str(xr))
             lxr.append(xr)
         if (fxu * fxr > 0 and fxl * fxr > 0):
             print("No tiene raiz")
  else:
     print("No tiene raiz")
biseccion()
plt.plot(lxr)  
plt.show()
# Out:
# METODO DE BISECCION:
# El valor de Xr es: 1.25
# El valor de Xr es: 1.625
# El valor de Xr es: 1.4375

# %%
#EJERCICIO #4#
import matplotlib.pyplot as plt
lxr = list()

def biseccion(xl = 1, xu = 3):
  print("METODO DE BISECCION: ")
  fxu=((xu**3.5) - (80))
  fxl = ((xl**3.5) - (80))
  if (fxu * fxl < 0):
     xr = (xl + xu) / 2
     fxr = ((5 * (xr**3)) + (5 * xr**2) + (6 * xr) - 2)
     print("El valor de Xr es: " + str(xr))
     lxr.append(xr)
     num = 1
     while num < 2:
         num = num + 1
         if (fxu * fxr < 0):             
             xl = xr
             fxu=((xu**3.5) - (80))
             fxl = ((xl**3.5) - (80))
             xr = (xl + xu) / 2
             fxr = ((xr**3.5) - (80))          
             print("El valor de Xr es: " + str(xr))
             lxr.append(xr)
         if (fxl * fxr < 0):
             xu = xr
             fxu=((xu**3.5) - (80))
             fxl = ((xl**3.5) - (80))
             xr = (xl + xu) / 2
             fxr = ((xr**3.5) - (80))     
             print("El valor de Xr es: " + str(xr))
             lxr.append(xr)
         if (fxu * fxr > 0 and fxl * fxr > 0):
             print("No tiene raiz")
  else:
     print("No tiene raiz")
biseccion()
plt.plot(lxr)  
plt.show()
# Out:
# METODO DE BISECCION:
# No tiene raiz

# %%
#EJERCICIO #4#
import matplotlib.pyplot as plt

def falsaPosicion(xl = 1, xu = 3):
    print("METODO DE FALSA POSICION: ")
    fxu=((xu**3.5) - (80))
    fxl = ((xl**3.5) - (80))
    lxr = list()
    if(fxu * fxl < 0):
        xr = (xu - ((fxu * (xl - xu) / (fxl - fxu))))
        fxr =((-0.5 * (xr**2)) + (2.5 * xr) + 4.5)
        lxr.append(xr)
        print("El valor de Xr es: " + str(xr))
        er = 1
        while er > (10**-5):
            if(fxu * fxr < 0):
                xl = xr
                fxl =((xl**3.5) - (80))
                fxu =((xu**3.5) - (80))
                xr = (xu - ((fxu * (xl - xu) / (fxl - fxu))))
                fxr =((xr**3.5) - (80))
                er=(xr-xl)/xr
                lxr.append(xr)
                print("El valor de Xr es: " + str(xr))
            if (fxl * fxr < 0):
                xu=xr
                fxl = ((xl**3.5) - (80))
                fxu = ((xu**3.5) - (80))
                xr = (xu - ((fxu * (xl - xu) / (fxl - fxu))))
                fxr = ((xr**3.5) - (80))
                er = (xr - xl) / xr
                lxr.append(xr)
                print("El valor de Xr es: " + str(xr))
            if (fxu * fxr > 0 and fxl * fxr > 0):
                print("No tiene raiz, fin del programa")
        plt.plot(lxr)
        plt.show
    else:
        print("No tiene raiz, fin del programa")
falsaPosicion()
# Out:
# METODO DE FALSA POSICION:
# No tiene raiz, fin del programa
